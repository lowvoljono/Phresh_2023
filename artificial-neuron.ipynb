# %% [markdown]
# # Activating Your First Artificial Neuron

# %% [markdown]
# epoch is # of iterations

# %%
# Initial imports
import pandas as pd
import numpy as np
from sklearn.datasets import make_blobs, make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %matplotlib inline

# %% [markdown]
# ## Using a Single Neuron for Binary Classification
#
# ### Creating Dummy Data

# %%
# Generate 1000 demo data samples with 2 features and two centers
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# %%
# Transforming y to a vertical vector
y = y.reshape(-1, 1)
y.shape
# Out:
# (1000, 1)

# %%
# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y
df.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   5.478098   7.203714       1
# 1  -8.428483   4.121889       0
# 2  -7.905447   3.323639       0
# 3   6.411041   5.523013       1
# 4   7.288599   6.171226       1

# %%
# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %% [markdown]
#  ### Data Preprocessing
#
#  Use `train_test_split` to create training and testing data.

# %%
# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %% [markdown]
#  Scale the data using the `StandarScaler`.

# %%
# Create scaler instance
X_scaler = StandardScaler()

# %%
# Fit the scaler
X_scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
#  ### Neural Network Model Creation

# %%
# Create a sequential model
neuron = Sequential()

# %% [markdown]
# The initial step is to add the first layer of our neural network.
#
# ![First Layer](../Images/tensorflow-neuron-layer-1.png)

# %%
# First layer
number_inputs = 2
number_hidden_nodes = 3

neuron.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))
# Out:
# 2023-03-13 20:28:57.770670: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-13 20:28:57.771198: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# We finish creating our neural network by adding the output layer.
#
# ![Output layer](../Images/tensorflow-neuron-output-layer.png)

# %%
# Output layer
number_classes = 1

neuron.add(Dense(units=number_classes, activation="sigmoid"))

# %%
# Model summary
neuron.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 3)                 9
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### number of parameters =
#
# 'number of inputs *  number of hidden layers + number of inputs'
#
#
# so 3 x 2 + 3?

# %% [markdown]
#  ### Compile the Model

# %%
# Compile model
neuron.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
#  ### Fit the Model

# %%
# Fitting the model with linear dummy data
model = neuron.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Train on 750 samples
# Epoch 1/100
# 750/750 [==============================] - 1s 1ms/sample - loss: 0.5510 - accuracy: 0.5067
# Epoch 2/100
# 750/750 [==============================] - 0s 56us/sample - loss: 0.5266 - accuracy: 0.5707
# Epoch 3/100
# 750/750 [==============================] - 0s 54us/sample - loss: 0.5049 - accuracy: 0.6373
# Epoch 4/100
# 750/750 [==============================] - 0s 50us/sample - loss: 0.4857 - accuracy: 0.7227
# Epoch 5/100
# 750/750 [==============================] - 0s 43us/sample - loss: 0.4684 - accuracy: 0.8040
# Epoch 6/100
# 750/750 [==============================] - 0s 52us/sample - loss: 0.4529 - accuracy: 0.8547
# Epoch 7/100
# 750/750 [==============================] - 0s 49us/sample - loss: 0.4387 - accuracy: 0.9053
# Epoch 8/100
# Epoch 100/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0735 - accuracy: 1.0000

# %% [markdown]
#  ### Evaluate the Model
#
#  #### Plotting the Loss Function and Accuracy

# %% [markdown]
# The iterations of the loss functions: (1) starts rough and high error (n) ends with near 0 loss

# %%
# Create a DataFrame with the history dictionary
df = pd.DataFrame(model.history, index=range(1, len(model.history["loss"]) + 1))

# Plot the loss
df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %% [markdown]
#  #### Evaluating the Model Using Testing Data

# %%
# Evaluate the model fit with linear dummy data
model_loss, model_accuracy = neuron.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 250/1 - 0s - loss: 0.0777 - accuracy: 1.0000
# Loss: 0.06871672075986862, Accuracy: 1.0

# %% [markdown]
#  ### Making Predictions with New Data

# %%
# Create 10 new samples of dummy data
new_X, new_y = make_blobs(n_samples=10, centers=2, n_features=2, random_state=78)

# %%
# Making predictions
predictions = (neuron.predict(new_X) > 0.5).astype("int32")
results = pd.DataFrame({"predictions": predictions.ravel(), "actual": new_y})
results.head(10)
# Out:
#    predictions  actual
# 0            1       0
# 1            1       1
# 2            0       0
# 3            1       1
# 4            1       0
# 5            1       0
# 6            1       1
# 7            1       1
# 8            1       1
# 9            1       0

# %% [markdown]
# ---

# %% [markdown]
# # Using a Single Neuron for Non-Linear Data
#
# ### Creating Demo Data:

# %%
# Creating dummy non-linear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# %%
# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# %%
# Creating a DataFrame to plot the non-linear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons
df_moons.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   0.676217   0.815220       0
# 1   1.487143  -0.210519       1
# 2  -1.027709   0.354966       0
# 3   0.236012   1.025531       0
# 4   1.856695  -0.042783       1

# %%
# Plotting the non-linear dummy data
df_moons.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %% [markdown]
# ### Data Preprocessing
#
# Use `train_test_split` to create training and testing data.

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# %% [markdown]
#  Scale the data

# %%
# Create the scaler instance
X_moon_scaler = StandardScaler()

# %%
# Fit the scaler
X_moon_scaler.fit(X_moon_train)
# Out:
# StandardScaler()

# %%
# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %% [markdown]
#  ### Fit the Model

# %%
# Training the model with the non-linear data
model_moon = neuron.fit(X_moon_train_scaled, y_moon_train, epochs=100)
# Out:
# Train on 750 samples
# Epoch 1/100
# 750/750 [==============================] - 0s 113us/sample - loss: 1.0390 - accuracy: 0.5000
# Epoch 2/100
# 750/750 [==============================] - 0s 54us/sample - loss: 0.8043 - accuracy: 0.5520
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2440 - accuracy: 0.9027
# Epoch 75/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2436 - accuracy: 0.9027
# Epoch 76/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2432 - accuracy: 0.9027
# Epoch 77/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2428 - accuracy: 0.9040
# Epoch 78/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2424 - accuracy: 0.9027
# Epoch 79/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2421 - accuracy: 0.9027
# Epoch 80/100
# 750/750 [==============================] - 0s 34us/sample - loss: 0.2417 - accuracy: 0.9027
# Epoch 81/100
# 750/750 [==============================] - 0s 34us/sample - loss: 0.2413 - accuracy: 0.9027
# Epoch 82/100
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2409 - accuracy: 0.9027
# Epoch 83/100
# 750/750 [==============================] - 0s 34us/sample - loss: 0.2406 - accuracy: 0.9027
# Epoch 84/100
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2403 - accuracy: 0.9027
# Epoch 85/100
# 750/750 [==============================] - 0s 75us/sample - loss: 0.2399 - accuracy: 0.9027
# Epoch 86/100
# 750/750 [==============================] - 0s 34us/sample - loss: 0.2396 - accuracy: 0.9027
# Epoch 87/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2392 - accuracy: 0.9027
# Epoch 88/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2388 - accuracy: 0.9027
# Epoch 89/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2385 - accuracy: 0.9027
# Epoch 90/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2382 - accuracy: 0.9040
# Epoch 91/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2379 - accuracy: 0.9053
# Epoch 92/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2376 - accuracy: 0.9040
# Epoch 93/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2371 - accuracy: 0.9053
# Epoch 94/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2368 - accuracy: 0.9053
# Epoch 95/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2365 - accuracy: 0.9053
# Epoch 96/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2361 - accuracy: 0.9053
# Epoch 97/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2359 - accuracy: 0.9040
# Epoch 98/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2354 - accuracy: 0.9053
# Epoch 99/100
# 750/750 [==============================] - 0s 34us/sample - loss: 0.2352 - accuracy: 0.9053
# Epoch 100/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2347 - accuracy: 0.9053

# %% [markdown]
#  ### Evaluate the Model
#
#  #### Plotting the Loss Function and Accuracy

# %%
# Create a DataFrame with the history dictionary
df_moon = pd.DataFrame(
    model_moon.history, index=range(1, len(model_moon.history["loss"]) + 1)
)

# Plot the loss
df_moon.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
df_moon.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %% [markdown]
#  #### Evaluating the Model Using Testing Data

# %%
# Evaluate the model using non-linear data
model_moon_loss, model_moon_accuracy = neuron.evaluate(
    X_moon_test_scaled, y_moon_test, verbose=2
)
print(f"Loss: {model_moon_loss}, Accuracy: {model_moon_accuracy}")
# Out:
# 250/1 - 0s - loss: 0.2208 - accuracy: 0.8640
# Loss: 0.2484040982723236, Accuracy: 0.8640000224113464

# %% [markdown]
#  ### Making Predictions

# %%
# Create demo data
X_new_moons, y_new_moons = make_moons(n_samples=10, noise=0.08, random_state=78)

# %%
# Making predictions
predictions_moon = (neuron.predict(X_new_moons) > 0.5).astype("int32")

results = pd.DataFrame({"predictions": predictions_moon.ravel(), "actual": y_new_moons})
results.head(10)
# Out:
#    predictions  actual
# 0            0       0
# 1            0       0
# 2            0       0
# 3            1       1
# 4            1       1
# 5            0       0
# 6            1       0
# 7            1       1
# 8            1       1
# 9            0       1

# %%
results.plot()
# Out:
# <AxesSubplot:>
